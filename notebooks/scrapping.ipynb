# %%
# %cd ..
# Out:
# /home/nikita/edu/inno-courses/S25/dwav/assignment-1

# %% [markdown]
# # Imports

# %%
import json
import requests
from bs4 import BeautifulSoup # parsing tool for wikipedia 
import sqlite3 as sql # database tool

# %% [markdown]
# # Parsing the Page

# %%
page_url = "https://en.wikipedia.org/wiki/List_of_highest-grossing_films" # wikipedia page url
base_wiki_url = "https://en.wikipedia.org" # base url for accessing additional pages
response = requests.get(page_url) 
soup = BeautifulSoup(response.text, "html.parser")

# %%
tables = soup.find_all("table", class_="wikitable")
films_table = tables[0]

rows = films_table.find_all("tr")
films = []

# function to convert string representing revenue to int
def str2int(string: str) -> int:
    numeric = [char for char in string if char.isnumeric()]
    return int("".join(numeric))

# iterate through rows (except header row) and extract film data
for row in rows[1:]:
    cells = row.find_all("td")
    headers = row.find_all("th")

    film_href = headers[0].find_all("a")[0]

    # collect all available data from the row
    film = {
        "year": cells[3].text.strip(),
        "title": film_href.text.strip(),
        "revenue": str2int(cells[2].text.strip()),
        "href": film_href["href"], # we will use this to access director and country data
    }

    films.append(film)
films
# Out:
# [{'year': '2009',
#   'title': 'Avatar',
#   'revenue': 2923706026,
#   'href': '/wiki/Avatar_(2009_film)'},
#  {'year': '2019',
#   'title': 'Avengers: Endgame',
#   'revenue': 2797501328,
#   'href': '/wiki/Avengers:_Endgame'},
#  {'year': '2022',
#   'title': 'Avatar: The Way of Water',
#   'revenue': 2320250281,
#   'href': '/wiki/Avatar:_The_Way_of_Water'},
#  {'year': '1997',
#   'title': 'Titanic',
#   'revenue': 2257844554,
#   'href': '/wiki/Titanic_(1997_film)'},
#  {'year': '2015',
#   'title': 'Star Wars: The Force Awakens',
#   'revenue': 2068223624,
#   'href': '/wiki/Star_Wars:_The_Force_Awakens'},
#  {'year': '2018',
#   'title': 'Avengers: Infinity War',
#   'revenue': 2048359754,
#   'href': '/wiki/Avengers:_Infinity_War'},
#  {'year': '2021',
#   'title': 'Spider-Man: No Way Home',
#   'revenue': 1922598800,
#   'href': '/wiki/Spider-Man:_No_Way_Home'},
#  {'year': '2024',
#   'title': 'Inside Out 2',
#   'revenue': 1698863816,
#   'href': '/wiki/Inside_Out_2'},
#  {'year': '2015',
#   'title': 'Jurassic World',
#   'revenue': 1671537444,
#   'href': '/wiki/Jurassic_World'},
#  {'year': '2025',
#   'title': 'Ne Zha 2',
#   'revenue': 1657050000,
#   'href': '/wiki/Ne_Zha_2'},
#  {'year': '2019',
#   'title': 'The Lion King',
#   'revenue': 1656943394,
#   'href': '/wiki/The_Lion_King_(2019_film)'},
#  {'year': '2012',
#   'title': 'The Avengers',
#   'revenue': 1518815515,
#   'href': '/wiki/The_Avengers_(2012_film)'},
#  {'year': '2015',
#   'title': 'Furious 7',
#   'revenue': 1515341399,
#   'href': '/wiki/Furious_7'},
#  {'year': '2022',
#   'title': 'Top Gun: Maverick',
#   'revenue': 1495696292,
#   'href': '/wiki/Top_Gun:_Maverick'},
#  {'year': '2019',
#   'title': 'Frozen 2',
#   'revenue': 1450026933,
#   'href': '/wiki/Frozen_2'},
#  {'year': '2023',
#   'title': 'Barbie',
#   'revenue': 1447038421,
#   'href': '/wiki/Barbie_(film)'},
#  {'year': '2015',
#   'title': 'Avengers: Age of Ultron',
#   'revenue': 1402809540,
#   'href': '/wiki/Avengers:_Age_of_Ultron'},
#  {'year': '2023',
#   'title': 'The Super Mario Bros. Movie',
#   'revenue': 1362566989,
#   'href': '/wiki/The_Super_Mario_Bros._Movie'},
#  {'year': '2018',
#   'title': 'Black Panther',
#   'revenue': 1347280838,
#   'href': '/wiki/Black_Panther_(film)'},
#  {'year': '2011',
#   'title': 'Harry Potter and the Deathly Hallows – Part 2',
#   'revenue': 1342139727,
#   'href': '/wiki/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2'},
#  {'year': '2024',
#   'title': 'Deadpool & Wolverine',
#   'revenue': 1338073645,
#   'href': '/wiki/Deadpool_%26_Wolverine'},
#  {'year': '2017',
#   'title': 'Star Wars: The Last Jedi',
#   'revenue': 1332539889,
#   'href': '/wiki/Star_Wars:_The_Last_Jedi'},
#  {'year': '2018',
#   'title': 'Jurassic World: Fallen Kingdom',
#   'revenue': 1308473425,
#   'href': '/wiki/Jurassic_World:_Fallen_Kingdom'},
#  {'year': '2013',
#   'title': 'Frozen',
#   'revenue': 1290000000,
#   'href': '/wiki/Frozen_(2013_film)'},
#  {'year': '2017',
#   'title': 'Beauty and the Beast',
#   'revenue': 1263521126,
#   'href': '/wiki/Beauty_and_the_Beast_(2017_film)'},
#  {'year': '2018',
#   'title': 'Incredibles 2',
#   'revenue': 1242805359,
#   'href': '/wiki/Incredibles_2'},
#  {'year': '2017',
#   'title': 'The Fate of the Furious',
#   'revenue': 81238764765,
#   'href': '/wiki/The_Fate_of_the_Furious'},
#  {'year': '2013',
#   'title': 'Iron Man 3',
#   'revenue': 1214811252,
#   'href': '/wiki/Iron_Man_3'},
#  {'year': '2015',
#   'title': 'Minions',
#   'revenue': 1159444662,
#   'href': '/wiki/Minions_(film)'},
#  {'year': '2016',
#   'title': 'Captain America: Civil War',
#   'revenue': 1153337496,
#   'href': '/wiki/Captain_America:_Civil_War'},
#  {'year': '2018',
#   'title': 'Aquaman',
#   'revenue': 1148528393,
#   'href': '/wiki/Aquaman_(film)'},
#  {'year': '2003',
#   'title': 'The Lord of the Rings: The Return of the King',
#   'revenue': 1147997407,
#   'href': '/wiki/The_Lord_of_the_Rings:_The_Return_of_the_King'},
#  {'year': '2019',
#   'title': 'Spider-Man: Far From Home',
#   'revenue': 1132679685,
#   'href': '/wiki/Spider-Man:_Far_From_Home'},
#  {'year': '2019',
#   'title': 'Captain Marvel',
#   'revenue': 1128274794,
#   'href': '/wiki/Captain_Marvel_(film)'},
#  {'year': '2011',
#   'title': 'Transformers: Dark of the Moon',
#   'revenue': 1123794079,
#   'href': '/wiki/Transformers:_Dark_of_the_Moon'},
#  {'year': '2012',
#   'title': 'Skyfall',
#   'revenue': 1108594137,
#   'href': '/wiki/Skyfall'},
#  {'year': '2014',
#   'title': 'Transformers: Age of Extinction',
#   'revenue': 1104054072,
#   'href': '/wiki/Transformers:_Age_of_Extinction'},
#  {'year': '2012',
#   'title': 'The Dark Knight Rises',
#   'revenue': 1081169825,
#   'href': '/wiki/The_Dark_Knight_Rises'},
#  {'year': '2019',
#   'title': 'Joker',
#   'revenue': 1074458282,
#   'href': '/wiki/Joker_(2019_film)'},
#  {'year': '2019',
#   'title': 'Star Wars: The Rise of Skywalker',
#   'revenue': 1074144248,
#   'href': '/wiki/Star_Wars:_The_Rise_of_Skywalker'},
#  {'year': '2019',
#   'title': 'Toy Story 4',
#   'revenue': 1073394593,
#   'href': '/wiki/Toy_Story_4'},
#  {'year': '2010',
#   'title': 'Toy Story 3',
#   'revenue': 1066970811,
#   'href': '/wiki/Toy_Story_3'},
#  {'year': '2006',
#   'title': "Pirates of the Caribbean: Dead Man's Chest",
#   'revenue': 1066179747,
#   'href': '/wiki/Pirates_of_the_Caribbean:_Dead_Man%27s_Chest'},
#  {'year': '2016',
#   'title': 'Rogue One: A Star Wars Story',
#   'revenue': 1057420387,
#   'href': '/wiki/Rogue_One:_A_Star_Wars_Story'},
#  {'year': '2019',
#   'title': 'Aladdin',
#   'revenue': 1050693953,
#   'href': '/wiki/Aladdin_(2019_film)'},
#  {'year': '1999',
#   'title': 'Star Wars: Episode I – The Phantom Menace',
#   'revenue': 1046515409,
#   'href': '/wiki/Star_Wars:_Episode_I_%E2%80%93_The_Phantom_Menace'},
#  {'year': '2024',
#   'title': 'Moana 2',
#   'revenue': 1045751565,
#   'href': '/wiki/Moana_2'},
#  {'year': '2011',
#   'title': 'Pirates of the Caribbean: On Stranger Tides',
#   'revenue': 1045713802,
#   'href': '/wiki/Pirates_of_the_Caribbean:_On_Stranger_Tides'},
#  {'year': '1993',
#   'title': 'Jurassic Park',
#   'revenue': 1037535230,
#   'href': '/wiki/Jurassic_Park_(film)'},
#  {'year': '2017',
#   'title': 'Despicable Me 3',
#   'revenue': 1034800131,
#   'href': '/wiki/Despicable_Me_3'}]

# %%
# We do a lot of consecutive requests, so we need to handle cases when the request fails
def retry(max_retries: int = 3):
    def decorator(func):
        def wrapper(*args, **kwargs):
            retries = 0
            while retries < max_retries:
                try:
                    return func(*args, **kwargs)
                except Exception:
                    retries += 1
            raise Exception

        return wrapper

    return decorator


# this function will parse film page and extract country data
@retry()
def get_country(href: str) -> str:
    response = requests.get(base_wiki_url + href)
    soup = BeautifulSoup(response.text, "html.parser")
    data = soup.select_one("table", class_="infobox")
    try:
        country = data.find("th", string="Country").find_next("td").text.strip()
    except Exception:
        country_td = data.find("th", string="Countries").find_next("td")
        ul = country_td.find("ul")
        country = (
            ", ".join([li.text.strip() for li in ul.find_all("li")])
            if ul
            else country_td.text.strip()
        )
    return country


# this function will parse film page and extract director data
@retry()
def get_director(href: str) -> str:
    response = requests.get(base_wiki_url + href)
    soup = BeautifulSoup(response.text, "html.parser")
    data = soup.select_one("table", class_="infobox")
    director_td = data.find("th", string="Directed by").find_next("td")
    director_list = director_td.find("ul")
    director = (
        ", ".join([li.text.strip() for li in director_list.find_all("li")])
        if director_list
        else director_td.text.strip()
    )
    return director


# parse film pages and extract additional data
# if our script fails to parse the page, we will set the value to "NONE"
# and print the name of problematic film
for film in films:
    try:
        film["country"] = get_country(film["href"])
    except Exception:
        film["country"] = "NONE"
        print(f"Failed to get country for {film['title']}")

    try:
        film["director"] = get_director(film["href"])
    except Exception:
        film["director"] = "NONE"
        print(f"Failed to get director for {film['title']}")
# Out:
# Failed to get country for Ne Zha 2
# Failed to get director for Ne Zha 2

# %% [markdown]
# `Ne Zha 2` has a deviant page structure, so we set data manually

# %%
for film in films:
    if film["title"] == "Ne Zha 2":
        film["country"] = "China"
        film["director"] = "Jiaozi"

# %% [markdown]
# # Creating a DataBase

# %%
# We will use SQLite to store our data
conn = sql.connect("data/films.db")
cursor = conn.cursor()

# This command is needed to make it possible to rerun this cell
cursor.execute("DROP TABLE IF EXISTS films")

# Schema is the same is in assignment instruction
cursor.execute(
    """
    CREATE TABLE IF NOT EXISTS films (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        title TEXT NOT NULL,
        release_year INTEGER,
        director TEXT,
        box_office REAL,
        country TEXT
    )
    """
)

# Insert film data one by one
for film in films:
    cursor.execute(
        """
        INSERT INTO films (title, release_year, director, box_office, country)
        VALUES (?, ?, ?, ?, ?)
        """,
        (
            film["title"],
            film["year"],
            film["director"],
            film["revenue"],
            film["country"],
        ),
    )

conn.commit()

# %%
# check if data was inserted correctly
cursor.execute("SELECT * FROM films").fetchall()
# Out:
# [(1,
#   'Avatar',
#   2009,
#   'James Cameron',
#   2923706026.0,
#   'United Kingdom[2], United States[2]'),
#  (2,
#   'Avengers: Endgame',
#   2019,
#   'Anthony Russo, Joe Russo',
#   2797501328.0,
#   'United States'),
#  (3,
#   'Avatar: The Way of Water',
#   2022,
#   'James Cameron',
#   2320250281.0,
#   'United States'),
#  (4, 'Titanic', 1997, 'James Cameron', 2257844554.0, 'United States'),
#  (5,
#   'Star Wars: The Force Awakens',
#   2015,
#   'J. J. Abrams',
#   2068223624.0,
#   'United States'),
#  (6,
#   'Avengers: Infinity War',
#   2018,
#   'Anthony Russo, Joe Russo',
#   2048359754.0,
#   'United States'),
#  (7,
#   'Spider-Man: No Way Home',
#   2021,
#   'Jon Watts',
#   1922598800.0,
#   'United States'),
#  (8, 'Inside Out 2', 2024, 'Kelsey Mann', 1698863816.0, 'United States'),
#  (9, 'Jurassic World', 2015, 'Colin Trevorrow', 1671537444.0, 'United States'),
#  (10, 'Ne Zha 2', 2025, 'Jiaozi', 1657050000.0, 'China'),
#  (11, 'The Lion King', 2019, 'Jon Favreau', 1656943394.0, 'United States'),
#  (12, 'The Avengers', 2012, 'Joss Whedon', 1518815515.0, 'United States'),
#  (13, 'Furious 7', 2015, 'James Wan', 1515341399.0, 'United States China'),
#  (14,
#   'Top Gun: Maverick',
#   2022,
#   'Joseph Kosinski',
#   1495696292.0,
#   'United States'),
#  (15,
#   'Frozen 2',
#   2019,
#   'Chris Buck, Jennifer Lee',
#   1450026933.0,
#   'United States'),
#  (16,
#   'Barbie',
#   2023,
#   'Greta Gerwig',
#   1447038421.0,
#   'United States[2][3], United Kingdom[3]'),
#  (17,
#   'Avengers: Age of Ultron',
#   2015,
#   'Joss Whedon',
#   1402809540.0,
#   'United States'),
#  (18,
#   'The Super Mario Bros. Movie',
#   2023,
#   'Aaron Horvath, Michael Jelenic',
#   1362566989.0,
#   'United States'),
#  (19, 'Black Panther', 2018, 'Ryan Coogler', 1347280838.0, 'United States'),
#  (20,
#   'Harry Potter and the Deathly Hallows – Part 2',
#   2011,
#   'David Yates',
#   1342139727.0,
#   'United Kingdom, United States'),
#  (21,
#   'Deadpool & Wolverine',
#   2024,
#   'Shawn Levy',
#   1338073645.0,
#   'United States'),
#  (22,
#   'Star Wars: The Last Jedi',
#   2017,
#   'Rian Johnson',
#   1332539889.0,
#   'United States'),
#  (23,
#   'Jurassic World: Fallen Kingdom',
#   2018,
#   'J. A. Bayona',
#   1308473425.0,
#   'China[4], United States[5]'),
#  (24,
#   'Frozen',
#   2013,
#   'Chris Buck, Jennifer Lee',
#   1290000000.0,
#   'United States'),
#  (25,
#   'Beauty and the Beast',
#   2017,
#   'Bill Condon',
#   1263521126.0,
#   'United States'),
#  (26, 'Incredibles 2', 2018, 'Brad Bird', 1242805359.0, 'United States'),
#  (27,
#   'The Fate of the Furious',
#   2017,
#   'F. Gary Gray',
#   81238764765.0,
#   'United States, China'),
#  (28, 'Iron Man 3', 2013, 'Shane Black', 1214811252.0, 'United States'),
#  (29,
#   'Minions',
#   2015,
#   'Pierre Coffin, Kyle Balda',
#   1159444662.0,
#   'United States'),
#  (30,
#   'Captain America: Civil War',
#   2016,
#   'Anthony RussoJoe Russo, Anthony Russo, Joe Russo',
#   1153337496.0,
#   'United States'),
#  (31, 'Aquaman', 2018, 'James Wan', 1148528393.0, 'United States'),
#  (32,
#   'The Lord of the Rings: The Return of the King',
#   2003,
#   'Peter Jackson',
#   1147997407.0,
#   'New Zealand[1], Germany[3], United States[1]'),
#  (33,
#   'Spider-Man: Far From Home',
#   2019,
#   'Jon Watts',
#   1132679685.0,
#   'United States'),
#  (34,
#   'Captain Marvel',
#   2019,
#   'Anna BodenRyan Fleck',
#   1128274794.0,
#   'United States'),
#  (35,
#   'Transformers: Dark of the Moon',
#   2011,
#   'Michael Bay',
#   1123794079.0,
#   'United States'),
#  (36,
#   'Skyfall',
#   2012,
#   'Sam Mendes',
#   1108594137.0,
#   'United Kingdom[4], United States[1]'),
#  (37,
#   'Transformers: Age of Extinction',
#   2014,
#   'Michael Bay',
#   1104054072.0,
#   'United States'),
#  (38,
#   'The Dark Knight Rises',
#   2012,
#   'Christopher Nolan',
#   1081169825.0,
#   'United States[2], United Kingdom[2]'),
#  (39, 'Joker', 2019, 'Todd Phillips', 1074458282.0, 'United States'),
#  (40,
#   'Star Wars: The Rise of Skywalker',
#   2019,
#   'J. J. Abrams',
#   1074144248.0,
#   'United States'),
#  (41, 'Toy Story 4', 2019, 'Josh Cooley', 1073394593.0, 'United States'),
#  (42, 'Toy Story 3', 2010, 'Lee Unkrich', 1066970811.0, 'United States'),
#  (43,
#   "Pirates of the Caribbean: Dead Man's Chest",
#   2006,
#   'Gore Verbinski',
#   1066179747.0,
#   'United States'),
#  (44,
#   'Rogue One: A Star Wars Story',
#   2016,
#   'Gareth Edwards',
#   1057420387.0,
#   'United States'),
#  (45, 'Aladdin', 2019, 'Guy Ritchie', 1050693953.0, 'United States'),
#  (46,
#   'Star Wars: Episode I – The Phantom Menace',
#   1999,
#   'George Lucas',
#   1046515409.0,
#   'United States'),
#  (47,
#   'Moana 2',
#   2024,
#   'David Derrick Jr.[1], Jason Hand[1], Dana Ledoux Miller[1]',
#   1045751565.0,
#   'United States'),
#  (48,
#   'Pirates of the Caribbean: On Stranger Tides',
#   2011,
#   'Rob Marshall',
#   1045713802.0,
#   'United States'),
#  (49,
#   'Jurassic Park',
#   1993,
#   'Steven Spielberg',
#   1037535230.0,
#   'United States'),
#  (50,
#   'Despicable Me 3',
#   2017,
#   'Pierre Coffin, Kyle Balda',
#   1034800131.0,
#   'United States')]

# %%
# For ease of deployment to GitHub pages, we will also save the data in JSON format
with open("data/films.json", "w") as file:
    json.dump(films, file)
